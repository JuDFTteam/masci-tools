# %% [markdown]
# # Put widgets including plot into a layout container
#
# Source: https://stackoverflow.com/a/48349991

# %%
from ipywidgets import *
import seaborn as sns
df = sns.load_dataset('iris')
import matplotlib.pyplot as plt

#plot
def plot_image(x):

    data = df

    if x != 'Select':
        xplot = data[x]
        sns.distplot(xplot)
        plt.show()

#define widgets
select_x = widgets.Dropdown(
        options=df.columns,
        value=df.columns[0],
        description='X'
    )

select_x.set_title  = 'x'

#assign widgets to tabs
tab_visualise = widgets.HBox([select_x])

#create tabs
tab_nest = widgets.Tab()
# tab_nest.children = [tab_visualise]
tab_nest.set_title(0, 'Visualise')


#interact function in isolation
f = interactive(plot_image, x = select_x);
tab_nest.children = [VBox(children = f.children)]
display(tab_nest)

# %% [markdown]
# # Seabon Showcase

# %%
from ipywidgets import *
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', height=2.5);

# %% [markdown]
# ## ugly matplotlib!

# %%
from IPython.display import display
import matplotlib.pyplot as plt
plt.style.use('classic')
####%matplotlib inline 
####%matplotlib nbagg
# %matplotlib widget
import numpy as np
import pandas as pd


# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)


# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');
# Out:
# ...
# <div id='f9de0962-11af-4c98-bd38-ee665b8de64b'></div>

# %% [markdown]
# ## beautify matplotlib with seaborn `sns.set()`!

# %%
import seaborn as sns
sns.set()

# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');
